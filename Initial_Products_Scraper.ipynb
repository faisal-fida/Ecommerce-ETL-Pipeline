# %%
import time
import requests
import json as Json
import pandas as pd

URL = "https://www.thredup.com/api/v1/shop/graphql"

# %%
payload_initial_products = {
    "operationName": "getItems",
    "variables": {
        "amount": 1000,
        "context": "plp",
        "filters": {
            "department_tags": ["women"],
            "category_tags": ["jeans"]
        },
        "itemQueryContext": {
            "clientModule": "core_pagination",
            "clientPageType": "shop-listings",
            "parentId": "746284908003811332",
            "queryId": "746284908003811330"
        },
        "page": 1,
        "query": "",
        "sortBy": "newest_first",
        "queryId": "746284908003811330",
        "target": None,
        "userInfo": {
            "bucketingKey": "3320415042",
            "hasPurchasedOrder": False,
            "isInternational": True,
            "mdcOverride": False,
            "userId": None,
            "userWarehouseIds": [3],
            "visitorId": "3320415042",
            "experiments": {
                "expedited_shipping_influencer": "off",
                "mobiledev_ss_updates_phase1": "excluded",
                "kustomer_integration": "on",
                "mobile_favorites_doubletap_Q2_2021": "on",
                "dynamic_favourites_replay": "excluded",
                "pwa_cleanout_subscription": "off",
                "pwa_sms_subscribe": "off",
                "pwa_best_sellers_hp": "excluded",
                "mobile_rebrand_co_flow": "off",
                "pwa_upfront_partner_cashout": "excluded",
                "co_consolidated_flow": "excluded",
                "mobile_idfa": "excluded",
                "android_ss_updates_phase1": "excluded",
                "pwa_wsx_fb": "off",
                "thrift_guarantee_insert": "excluded",
                "oct_21_2022_credit_drop": "off",
                "mobiledev_co_print_label": "excluded",
                "gen_z_curations": "excluded",
                "oct_2022_credit_drop": "off",
                "mobile_deleteUser": "off",
                "nov-2022-credit-drop": "off",
                "android_rebranded_checkout_V3": "excluded",
                "ios-cart-item-recs": "on",
                "mobiledev_debug_menu": "off",
                "ios_rebranded_checkout_V3": "excluded",
                "mobiledev_plp_apollo": "excluded",
                "credits_hold_release_v2": "on",
                "bags_return_tooltip": "on",
                "mobile_orderConfirmation_shipmentNotifications": "excluded",
                "pwa_pdp_shipping": "on",
                "native_universal_banner": "on",
                "pwa_images": "excluded",
                "loyalty_progress_bar": "excluded",
                "mobile_useAuth0API": "exclude",
                "seller_segment_plp_kit_block": "off",
                "mobile_fullstory": "excluded",
                "dropshipping_show_ew": "excluded",
                "facet_counts_v2": "excluded",
                "mobile_pdp_resize_photo": "excluded",
                "mobile_wsx_master": "excluded",
                "shipping_fees": "on",
                "collect_disliked_items": "excluded",
                "disc_sizes_v1_pwa": "excluded",
                "native_cms_rollout": "on",
                "heart_or_not_onboarding": "excluded",
                "track_item_visibility": "on",
                "pwa_promo_countdown": "excluded",
                "brands_filter_v1": "excluded",
                "mobile_onboarding_v1": "excluded",
                "heart_or_not_hp": "on",
                "track_item_visibility_native": "off",
                "ios_provisional_notif_2021_q2": "on",
                "pwa_amazonpay": "on",
                "pwa_paypal": "on",
                "native_pdp_measurements": "excluded",
                "gen_z_curations_tik_tok": "on_treatment",
                "loyalty_birthday_collection": "off",
                "mobile_thrift_the_look": "excluded",
                "mobile_performance_collection": "on",
                "mobile_close_sizeprofile": "excluded",
                "mobile_venmo": "excluded",
                "pwa_plp_billboard_carousel": "excluded",
                "co_multi_kits": "excluded",
                "pwa_afterpay": "off",
                "mobile_applepay_paypal_Q2_2021": "excluded",
                "mobile_rma": "off",
                "sale_price": "on",
                "native_visual_filter_faceted": "off",
                "smarter_delivery_timelines": "on",
                "mobile_medallia": "excluded",
                "zero_payout_brands": "on",
                "pwa_my_sizes_default": "excluded",
                "featuredpage_value_dollar_percent": "excluded",
                "ios_applepay_paypal": "on",
                "mobile_favorites_coachmark": "on",
                "mobile_hdyhau": "excluded",
                "pwa_wsx_master": "on_organic",
                "listing_window_update": "on",
                "attentive": "excluded",
                "my_cleanouts_awaiting_bags": "excluded",
                "pwa_giftcard_LP": "off",
                "pwa_custom_smartbanner_v2_ep": "off",
                "mobile_defaultfavorites": "on",
                "bag_sales_report": "off",
                "mobile_pdpbrands": "excluded",
                "android_pdp_endpoint": "excluded",
                "pwa_ttl_on_pdp": "excluded",
                "mobile_ss_ui_Q2_2021": "excluded",
                "billboard_and_ranking_split": "billboard",
                "native_searchbar_v1": "excluded",
                "mobile_logrocket": "off",
                "loyalty_points_2019": "excluded",
                "native_pdp_similar": "on",
                "increase_restocking_fees": "on",
                "cart_incentive_by_platform": "on",
                "native_best_sellers_fp": "excluded",
                "item_urgency": "on",
                "workday_career": "on",
                "pwa_pla_promo": "off",
                "auth0_release_pwa_signup": "excluded",
                "loyalty_tiered_program": "excluded",
                "disc_sizes_translations": "on",
                "mobiledev_mysizes_top_bottom": "excluded",
                "waive_kit_processing_fees_v2": "excluded",
                "recent_searches_full_query": "excluded",
                "global_native_mobile_split": "excluded",
                "seller_ugc": "off",
                "dynamic_removed_from_cart": "excluded",
                "mobile_customlp": "on",
                "pwa_ssn_form": "off",
                "pwa_cashapp": "off",
                "pwa_cashout_paypal_max": "100000",
                "mobile_tracking_v2": "on",
                "mobiledev_plp_links": "off",
                "favorites_replay_recent_discounted": "excluded",
                "order_conf_item_recs": "on",
                "kit_buyout": "on",
                "upfront_bag_fee": "excluded",
                "mobile_badgetest_v2_ios": "alltags",
                "mobiledev_notif_center": "off",
                "bingo_2022": "off",
                "cart_timer": "1_hour",
                "np_credit_drop_7_19": "excluded",
                "pwa_curation_test": "on",
                "pwa_quality_condition": "on",
                "pwa_applepay": "excluded",
                "pwa-atc-confirmation-test-2021-q4": "on",
                "native_rokt_ads": "on",
                "mobile_search_v2_fab_ios": "excluded",
                "use_looks_core": "on",
                "mobiledev_apple_login_v3": "off",
                "mobiledev_apq": "excluded",
                "mobile_usedatadog": "off",
                "order_request": "on",
                "resale_rundown": "on",
                "mobile_thredit": "excluded",
                "cleanout_options_experiment": "off",
                "mobiledev_override_crashes_with_non_fatal": "off",
                "mobile_ungated_ios": "on",
                "pwa_medallia": "on",
                "pwa_universal_banner": "on",
                "co_removed_processing_options": "on",
                "auth0_release_mobile_api": "excluded",
                "pwa_verify_email": "on",
                "mobile_mythredup": "on",
                "loyalty_october_comms": "excluded",
                "auth0_release": "on",
                "seller_segment_kit_content": "off",
                "shortcuts_v2": "excluded",
                "atc_item_recs": "excluded",
                "quality_confirmation_co_flow": "off",
                "pwa_experiments_evaluation": "on",
                "pwa_wsx_checkout": "on",
                "native_snowplow_tracking": "on",
                "pwa_search_feedback": "on",
                "afterpay": "off",
                "mobiledev_promo_influencer": "off"
            }
        },
        "excludes": {"warehouse_id": [20]}
    },
    "extensions": {"persistedQuery": {
        "version": 1,
        "sha256Hash": "3aa488084e9a33ece1e9d44c6507377dacdd7ffa93b8d83978457e5430a62368"
    }}
}

# %%
headers_initial_products = {
    "cookie": 'tup_jwt_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ2aXNpdG9yX2lkIjozMzIwNDE1MDQyfQ.QiZdIoVUDKuFeQM0hfJT3Pmu0jal8P9o6O95QbGAH7suAzCqpOP8Kg8XT1Eh25YUl33ahCxzSuihyTlxNdolNRb7ER3Jvhgs2WhENN9XXKJzo5aQgF63WbBa-uzC2S04hTAZexFjXmc2J8gq1I6TDu7OrAzyVdBr82v8oX92DgQs2Mtl4TXkz4U3ufmAh6n523wlC4gY34kbDsMfWdHv7YI4S5pebb4uUSQzKRCLFs9i6dUWQHy33H6NnsWX2UM7fZ0BbF6SKefEuMvhvGU16dMxjN-wkP0n6aqg1wCGhYOfke5XR7FXv1cvZ17e0WXziz5CwExqlbr4HCiHZLzsyA; visitor_id=3320415042; originating_url=https://www.thredup.com/product/women-cotton-white-house-black-market-brown-jeans/130744656; traffic_type=direct; sp=29052cc2-20df-4ca7-bdfb-486901644383; thredup_production_first_referral_code=organic; thredup_production_external_referrer=https://www.thredup.com; _sp_ses.ead3=*; visitor_id=3320415042; production_tup3_session=YkJMN1ZrY3p6dmoxL2tmbDE2M3JxS1lHK3R6c3ZwQXRUaVdKZnhERFpxd3FNbmdqczdTcnRMc3ZsQmhuMm0xSkp5MmhxODJTc3VMenFqNzNOZk41SXk3MjRVQkFTd1ZEUC9tMG1IOVI2NVRhcS9RK2VFWERjQTdkcUFFZmR3Vm4tLVhzbmtrR2ZGRzR0Z2hGTXZta0Vmanc9PQ==--869512092b994ebc4f5523932e9d182840895d1e; __cf_bm=taGndPi0k6v6uV4OuLdPHezh.YJCI9nnG0N_mGsZT_o-1678299158-0-AV3YOrWK2l+X0I2+svyN5PlP/si8+yJnWz6ZZfcQV4QE6hukhskFuUR2MZ+GyicDgJbcu6TwzlnO7mxDRdabNFkhjE9o3hAqkcr7H+nCnrdK; _sp_id.ead3=89154845-2a47-477d-96b6-b0f97c859478.1678241524.4.1678299162.1678281647.bcb830de-1bd4-4441-ac6d-2d3f333c7c5e.295ccb0c-8a19-43c4-80f2-10c02e68ab9c.a5ed6070-63b3-4e92-b1e7-67d65d4273e6.1678296876118.30',
    "authority": "www.thredup.com",
    "accept": "*/*",
    "accept-language": "en-PK,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,ru;q=0.6",
    'auth-token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ2aXNpdG9yX2lkIjozMzQ3MTAzODMwfQ.ukau1AkFXXLG8Ji_LMoPtFxt21Cg9AGgzVsu-A_lit6_zQj0Yx0y0dozO8Huhc0l-ONXfF0mhS5nnGZuR1cU9gN0TQs5pZz50_zktYOsibBkDFq8KMdwUizl0sIdusQLWfmJ_q34e_XmPM4lstyfcvjdGYFKiR4HAmxvfc3NsgrRhA3KSyIQ8fZzsh1UpLoCgcg6UQxK4Y4Ds3ADQ_pd5N3zlVbuIQJ4TEU8J3LirtW9bOXM8c_ObLiRfKgmWbacvva16jFLIXfv5CM0S2VA7Rhu90sdWbl7sljqu9lfbt9jklazQwOwwekL-_bg3tbXgeFAMY1stoD7fkJIVoP39w',
    "dnt": "1",
    "origin": "https://www.thredup.com",
    "referer": "https://www.thredup.com/women/jeans?department_tags=women&category_tags=jeans",
    "sec-ch-ua": '"Chromium";v="110", "Not A(Brand";v="24", "Google Chrome";v="110"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "sec-gpc": "1",
    "tuppt": "undefined",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36",
    "x-client-app": "pwa",
    "x-previous-referrer": "https://www.thredup.com",
    "x-tup-visitor-id": "3320415042"
}

# %%
payload_initial_products = {
    'operationName': 'getItems',
    'variables': {
        'amount': 1000,
        'context': 'plp',
        'filters': {
            'department_tags': [
                'women',
            ],
            'category_tags': [
                'jeans',
            ],
        },
        'itemQueryContext': {
            'clientModule': 'core_other',
            'clientPageType': 'shop-listings',
        },
        'page': 1,
        'query': '',
        "sortBy": "newest_first",
        'target': None,
        'userInfo': {
            'bucketingKey': '3320415043',
            'hasPurchasedOrder': False,
            'isInternational': True,
            'mdcOverride': False,
            'userId': None,
            'userWarehouseIds': [
                16,
                5,
            ],
            'visitorId': '3320415043',
        },
        'excludes': {
            'warehouse_id': [
                20,
            ],
        },
    },
    'extensions': {
        'persistedQuery': {
            'version': 1,
            'sha256Hash': 'd497d7f56926c26b91a852bf092559cf1b1081812eeb10205947be4a57a9826c',
        },
    },
}


cookies = {
    'tup_jwt_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ2aXNpdG9yX2lkIjozMzQ3MTAzODMwfQ.ukau1AkFXXLG8Ji_LMoPtFxt21Cg9AGgzVsu-A_lit6_zQj0Yx0y0dozO8Huhc0l-ONXfF0mhS5nnGZuR1cU9gN0TQs5pZz50_zktYOsibBkDFq8KMdwUizl0sIdusQLWfmJ_q34e_XmPM4lstyfcvjdGYFKiR4HAmxvfc3NsgrRhA3KSyIQ8fZzsh1UpLoCgcg6UQxK4Y4Ds3ADQ_pd5N3zlVbuIQJ4TEU8J3LirtW9bOXM8c_ObLiRfKgmWbacvva16jFLIXfv5CM0S2VA7Rhu90sdWbl7sljqu9lfbt9jklazQwOwwekL-_bg3tbXgeFAMY1stoD7fkJIVoP39w'
}

headers = {
    'authority': 'www.thredup.com',
    'auth-token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ2aXNpdG9yX2lkIjozMzQ3MTAzODMwfQ.ukau1AkFXXLG8Ji_LMoPtFxt21Cg9AGgzVsu-A_lit6_zQj0Yx0y0dozO8Huhc0l-ONXfF0mhS5nnGZuR1cU9gN0TQs5pZz50_zktYOsibBkDFq8KMdwUizl0sIdusQLWfmJ_q34e_XmPM4lstyfcvjdGYFKiR4HAmxvfc3NsgrRhA3KSyIQ8fZzsh1UpLoCgcg6UQxK4Y4Ds3ADQ_pd5N3zlVbuIQJ4TEU8J3LirtW9bOXM8c_ObLiRfKgmWbacvva16jFLIXfv5CM0S2VA7Rhu90sdWbl7sljqu9lfbt9jklazQwOwwekL-_bg3tbXgeFAMY1stoD7fkJIVoP39w',
    'content-type': 'application/json',
    'origin': 'https://www.thredup.com',
    'referer': 'https://www.thredup.com/women/jeans?department_tags=women&category_tags=jeans',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    'x-previous-referrer': 'https://www.thredup.com',
}

# %%
def post_request(URL, payload, headers, cookies):
    return requests.request("POST", URL, json=payload, headers=headers, cookies=cookies).json()

# %%
def json_variables(json_amount=119, json_page=2):
    payload_initial_products['variables']['amount'] = json_amount
    payload_initial_products['variables']['page'] = json_page

# %%
def get_initial_products(json_amount):
    #set payload and headers data for initial products
    data_initial_products = []
    start_time = time.time()
   
    for idx in range(1,100):
        print(f'Scraping Initial Products Page: {idx}', end='\r')
        json_variables(json_amount ,json_page=idx)
        try:
            data_initial_product = post_request(URL, payload_initial_products, headers, cookies)['data']['items']['nodes']
            if len(data_initial_product) == 0:
                print(idx, "There is no more products")
                break
            data_initial_products.append(data_initial_product)
        except Exception as e:
            print(f"\nError retrieving data_initial_product: {e} \n")
            pass
    
    end_time = time.time()
    print(f"Time taken to Scrape {idx} Pages: {end_time - start_time}")
    
    return data_initial_products

# %%
def parse_initial_products(data_initial_products):
    df_initial_product = pd.DataFrame()
    df_initial_products = pd.DataFrame()

    for data_initial_product in data_initial_products:
        df_initial_product = pd.DataFrame(data_initial_product)
        df_initial_products = pd.concat([df_initial_products, df_initial_product],ignore_index=True)
        
    print(f'There are: {df_initial_products["itemNumber"].duplicated().sum()} duplicated items in Data.')
    
    return df_initial_products

# %%
def main():
    data_initial_products = get_initial_products(json_amount=1000)
    df_initial_products = parse_initial_products(data_initial_products) 
    return data_initial_products, df_initial_products
    
data_initial_products, df_initial_products = main()
# Out:
# 51 There is no more productsge: 51
# Time taken to Scrape 51 Pages: 117.28949999809265
# There are: 21 duplicated items in Data.

# %%
df_initial_products = parse_initial_products(data_initial_products)
# Out:
# There are: 43 duplicated items in Data.

# %%
df_initial_products
# Out:
#       availability               brand  brandId  category categoryTags  \
# 0          InStock            Old Navy      279  Jeggings      [jeans]
# 1          InStock             D.Jeans    12330     Jeans      [jeans]
# 2          InStock     Jessica Simpson     2749     Jeans      [jeans]
# 3          InStock     Ann Taylor LOFT     1751     Jeans      [jeans]
# 4          InStock     & Other Stories    31400     Jeans      [jeans]
# ...            ...                 ...      ...       ...          ...
# 49995      InStock      New Directions    24853  Jeggings      [jeans]
# 49996      InStock              PacSun    21782     Jeans      [jeans]
# 49997      InStock             Express      807     Jeans      [jeans]
# 49998      InStock  Kut from the Kloth     8662     Jeans      [jeans]
# 49999      InStock              J.Crew     2518     Jeans      [jeans]
#
#        clearance            colorNames conditionOverrides    departmentTags  \
# ...

# %%
import pandas as pd

df_initial_products["merchandisingDepartment"].unique()
# Out:
# array(['women', 'X', 'plus', 'juniors'], dtype=object)

# %%
df_initial_products["price"]
# Out:
# 0        31.99
# 1        35.99
# 2        23.99
# 3        22.99
# 4        18.99
#          ...
# 49995    32.99
# 49996    21.99
# 49997    15.99
# 49998    33.99
# 49999    29.99
# Name: price, Length: 50000, dtype: object

# %%
df_initial_products.to_dict("records")
# Out:
# [{'availability': 'InStock',
#   'brand': "Denizen from Levi's",
#   'brandId': 3893,
#   'category': 'Jeans',
#   'categoryTags': ['jeans'],
#   'clearance': False,
#   'colorNames': ['Blue'],
#   'conditionOverrides': None,
#   'departmentTags': ['women'],
#   'favoriteCount': nan,
#   'favorites': None,
#   'hasConditionOverrides': None,
#   'hasInappropriateContent': None,
#   'id': 140408414,
#   'itemNumber': 143411981,
#   'materials': ['78% Cotton', '20% Polyester', '2% Elastane'],
#   'merchandisingDepartment': 'women',
#   'msrp': 32.0,
#   'newWithTags': False,
#   'occasionTags': [],
#   'photoIds': ['487947762', '487947808'],
#   'price': '15.99',
#   'promotion': None,
#   'sellthroughScore': 0.25808,
#   'sizeEquivalents': None,
#   'sizeLabel': 'Size 8',
#   'sizes': ['8'],
#   'state': 'listed',
#   'styleTags': [],
#   'supplierId': 54013669,
#   'sustainabilityImpactV2': {'category': 'jeans',
#    'glassesOfWater': 637.48,
#    'hoursOfLighting': 142.2,
# ...

# %%
len(list(set(df_initial_products['itemNumber'].unique().tolist())))
# Out:
# 49999

# %%
df_initial_products['itemNumber'].to_csv('itemNumber.txt', sep='\n', index=False, header=False)
df_initial_products.to_csv('df_initial_products.csv')
